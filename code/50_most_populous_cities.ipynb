# %%
import pandas as pd 
import numpy as np
import requests 
import constants
from pathlib import Path
import matplotlib.pyplot as plt
# Out:
# In /home/katie/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The savefig.frameon rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
# In /home/katie/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The verbose.level rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
# In /home/katie/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The verbose.fileo rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.

# %%
# data from wikipedia 
# https://en.wikipedia.org/wiki/List_of_United_States_cities_by_population
cities = constants.DATA_PATH.joinpath('2019_city_rank.csv')
df = pd.read_csv(str(cities))
df
# Out:
#     RANK             CITY                 STATE  2019_ESTIMATE  \
# 0      1         New York              New York        8336817
# 1      2      Los Angeles            California        3979576
# 2      3          Chicago              Illinois        2693976
# 3      4          Houston                 Texas        2320268
# 4      5          Phoenix               Arizona        1680992
# 5      6     Philadelphia          Pennsylvania        1584064
# 6      7      San Antonio                 Texas        1547253
# 7      8        San Diego            California        1423851
# 8      9           Dallas                 Texas        1343573
# 9     10         San Jose            California        1021795
# 10    11           Austin                 Texas         978908
# 11    12     Jacksonville               Florida         911507
# 12    13       Fort Worth                 Texas         909585
# 13    14         Columbus                  Ohio         898553
# 14    15        Charlotte        North Carolina         885708
# 15    16    San Francisco            California         881549
# 16    17     Indianapolis               Indiana         876384
# 17    18          Seattle            Washington         753675
# 18    19           Denver              Colorado         727211
# 19    20       Washington  District of Columbia         705749
# 20    21           Boston         Massachusetts         692600
# 21    22          El Paso                 Texas         681728
# 22    23        Nashville             Tennessee         670820
# 23    24          Detroit              Michigan         670031
# 24    25    Oklahoma City              Oklahoma         655057
# 25    26         Portland                Oregon         654741
# 26    27        Las Vegas                Nevada         651319
# 27    28          Memphis             Tennessee         651073
# 28    29       Louisville              Kentucky         617638
# 29    30        Baltimore              Maryland         593490
# ..   ...              ...                   ...            ...
# 70    71          Orlando               Florida         287442
# 71    72           Irvine            California         287401
# 72    73           Newark            New Jersey         282011
# 73    74           Durham        North Carolina         278993
# 74    75      Chula Vista            California         274492
# 75    76           Toledo                  Ohio         272779
# 76    77       Fort Wayne               Indiana         270402
# 77    78   St. Petersburg               Florida         265351
# 78    79           Laredo                 Texas         262491
# 79    80      Jersey City            New Jersey         262075
# 80    81         Chandler               Arizona         261165
# 81    82          Madison             Wisconsin         259680
# 82    83          Lubbock                 Texas         258862
# 83    84       Scottsdale               Arizona         258069
# 84    85             Reno                Nevada         255601
# 85    86          Buffalo              New York         255284
# 86    87          Gilbert               Arizona         254114
# 87    88         Glendale               Arizona         252381
# 88    89  North Las Vegas                Nevada         251974
# 89    90    Winston–Salem        North Carolina         247945
# 90    91       Chesapeake              Virginia         244835
# 91    92          Norfolk              Virginia         242742
# 92    93          Fremont            California         241110
# 93    94          Garland                 Texas         239928
# 94    95           Irving                 Texas         239798
# 95    96          Hialeah               Florida         233339
# 96    97         Richmond              Virginia         230436
# 97    98            Boise                 Idaho         228959
# 98    99          Spokane            Washington         222081
# 99   100      Baton Rouge             Louisiana         220236
#
#     2010_CENSUS\nCensus  CHANGE 2016_LAND_AREA_SQ_MI  2016_LAND_AREA_KM2  \
# 0               8175133  0.0198           301.5 sq mi          780.9 km2
# 1               3792621  0.0493           468.7 sq mi        1,213.9 km2
# 2               2695598   −0.06           227.3 sq mi          588.7 km2
# 3               2100263  0.1048           637.5 sq mi        1,651.1 km2
# 4               1445632  0.1628           517.6 sq mi        1,340.6 km2
# 5               1526006   0.038           134.2 sq mi          347.6 km2
# 6               1327407  0.1656           461.0 sq mi        1,194.0 km2
# 7               1307402  0.0891           325.2 sq mi          842.3 km2
# 8               1197816  0.1217           340.9 sq mi          882.9 km2
# 9                945942  0.0802           177.5 sq mi          459.7 km2
# 10               790390  0.2385           312.7 sq mi          809.9 km2
# 11               821784  0.1092           747.4 sq mi        1,935.8 km2
# 12               741206  0.2272           342.9 sq mi          888.1 km2
# 13               787033  0.1417           218.5 sq mi          565.9 km2
# 14               731424  0.2109           305.4 sq mi          791.0 km2
# 15               805235  0.0948            46.9 sq mi          121.5 km2
# 16               820445  0.0682           361.5 sq mi          936.3 km2
# 17               608660  0.2383            83.8 sq mi          217.0 km2
# 18               600158  0.2117           153.3 sq mi          397.0 km2
# 19               601723  0.1729            61.1 sq mi          158.2 km2
# 20               617594  0.1214            48.3 sq mi          125.1 km2
# 21               649121  0.0502           256.8 sq mi          665.1 km2
# 22               601222  0.1158           475.9 sq mi        1,232.6 km2
# 23               713777   −6.13           138.8 sq mi          359.5 km2
# 24               579999  0.1294           606.3 sq mi        1,570.3 km2
# 25               583776  0.1216           133.5 sq mi          345.8 km2
# 26               583756  0.1157           134.4 sq mi          348.1 km2
# 27               646889  0.0065           317.4 sq mi          822.1 km2
# 28               597337   0.034           263.5 sq mi          682.5 km2
# 29               620961   −4.42            80.9 sq mi          209.5 km2
# ..                  ...     ...                   ...                ...
# 70               238300  0.2062           105.2 sq mi          272.5 km2
# 71               212375  0.3533            65.6 sq mi          169.9 km2
# 72               277140  0.0176            24.1 sq mi           62.4 km2
# 73               228330  0.2219           109.8 sq mi          284.4 km2
# 74               243916  0.1254            49.6 sq mi          128.5 km2
# 75               287208   −5.02            80.7 sq mi          209.0 km2
# 76               253691  0.0659           110.6 sq mi          286.5 km2
# 77               244769  0.0841            61.8 sq mi          160.1 km2
# 78               236091  0.1118           101.1 sq mi          261.8 km2
# 79               247597  0.0585            14.8 sq mi           38.3 km2
# 80               236123  0.1061            64.9 sq mi          168.1 km2
# 81               233209  0.1135            77.0 sq mi          199.4 km2
# 82               229573  0.1276           124.6 sq mi          322.7 km2
# 83               217385  0.1872           183.9 sq mi          476.3 km2
# 84               225221  0.1349           107.3 sq mi          277.9 km2
# 85               261310   −2.31            40.4 sq mi          104.6 km2
# 86               208453   0.219            68.0 sq mi          176.1 km2
# 87               226721  0.1132            59.1 sq mi          153.1 km2
# 88               216961  0.1614            98.0 sq mi          253.8 km2
# 89               229617  0.0798           132.5 sq mi          343.2 km2
# 90               222209  0.1018           338.5 sq mi          876.7 km2
# 91               242803   −0.03            53.3 sq mi          138.0 km2
# 92               214089  0.1262            77.5 sq mi          200.7 km2
# 93               226876  0.0575            57.0 sq mi          147.6 km2
# 94               216290  0.1087            67.0 sq mi          173.5 km2
# 95               224669  0.0386            21.5 sq mi           55.7 km2
# 96               204214  0.1284            59.8 sq mi          154.9 km2
# 97               205671  0.1132            82.1 sq mi          212.6 km2
# 98               208916   0.063            68.7 sq mi          177.9 km2
# 99               229493   −4.03            85.9 sq mi          222.5 km2
#
#    2016_POPULATION_DENSITY_SQ_MI 2016_POPULATION_DENSITY_KM2  \
# 0                   28,317/sq mi                  10,933/km2
# 1                    8,484/sq mi                   3,276/km2
# 2                   11,900/sq mi                   4,600/km2
# 3                    3,613/sq mi                   1,395/km2
# 4                    3,120/sq mi                   1,200/km2
# 5                   11,683/sq mi                   4,511/km2
# 6                    3,238/sq mi                   1,250/km2
# 7                    4,325/sq mi                   1,670/km2
# 8                    3,866/sq mi                   1,493/km2
# 9                    5,777/sq mi                   2,231/km2
# 10                   3,031/sq mi                   1,170/km2
# 11                   1,178/sq mi                     455/km2
# 12                   2,491/sq mi                     962/km2
# 13                   3,936/sq mi                   1,520/km2
# 14                   2,757/sq mi                   1,064/km2
# 15                  18,569/sq mi                   7,170/km2
# 16                   2,366/sq mi                     914/km2
# 17                   8,405/sq mi                   3,245/km2
# 18                   4,521/sq mi                   1,746/km2
# 19                  11,148/sq mi                   4,304/km2
# 20                  13,938/sq mi                   5,381/km2
# 21                   2,660/sq mi                   1,030/km2
# 22                   1,388/sq mi                     536/km2
# 23                   4,847/sq mi                   1,871/km2
# 24                   1,053/sq mi                     407/km2
# 25                   4,793/sq mi                   1,851/km2
# 26                   4,709/sq mi                   1,818/km2
# 27                   2,056/sq mi                     794/km2
# 28                   2,339/sq mi                     903/km2
# 29                   7,598/sq mi                   2,934/km2
# ..                           ...                         ...
# 70                   2,635/sq mi                   1,017/km2
# 71                   4,057/sq mi                   1,566/km2
# 72                  11,691/sq mi                   4,514/km2
# 73                   2,395/sq mi                     925/km2
# 74                   5,387/sq mi                   2,080/km2
# 75                   3,451/sq mi                   1,332/km2
# 76                   2,391/sq mi                     923/km2
# 77                   4,223/sq mi                   1,631/km2
# 78                   2,544/sq mi                     982/km2
# 79                  17,848/sq mi                   6,891/km2
# 80                   3,813/sq mi                   1,472/km2
# 81                   3,280/sq mi                   1,270/km2
# 82                   2,027/sq mi                     783/km2
# 83                   1,341/sq mi                     518/km2
# 84                   2,286/sq mi                     883/km2
# 85                   6,359/sq mi                   2,455/km2
# 86                   3,487/sq mi                   1,346/km2
# 87                   4,161/sq mi                   1,607/km2
# 88                   2,436/sq mi                     941/km2
# 89                   1,828/sq mi                     706/km2
# 90                     703/sq mi                     271/km2
# 91                   4,599/sq mi                   1,776/km2
# 92                   3,008/sq mi                   1,161/km2
# 93                   4,122/sq mi                   1,592/km2
# 94                   3,557/sq mi                   1,373/km2
# 95                  10,995/sq mi                   4,245/km2
# 96                   3,732/sq mi                   1,441/km2
# 97                   2,718/sq mi                   1,049/km2
# 98                   3,144/sq mi                   1,214/km2
# 99                   2,651/sq mi                   1,024/km2
#
#                 LOCATION
# 0    40.6635°N 73.9387°W
# 1   34.0194°N 118.4108°W
# 2    41.8376°N 87.6818°W
# 3    29.7866°N 95.3909°W
# 4   33.5722°N 112.0901°W
# 5    40.0094°N 75.1333°W
# 6    29.4724°N 98.5251°W
# 7   32.8153°N 117.1350°W
# 8    32.7933°N 96.7665°W
# 9   37.2967°N 121.8189°W
# 10   30.3039°N 97.7544°W
# 11   30.3369°N 81.6616°W
# 12   32.7815°N 97.3467°W
# 13   39.9852°N 82.9848°W
# 14   35.2078°N 80.8310°W
# 15  37.7272°N 123.0322°W
# 16   39.7767°N 86.1459°W
# 17  47.6205°N 122.3509°W
# 18  39.7619°N 104.8811°W
# 19   38.9041°N 77.0172°W
# 20   42.3320°N 71.0202°W
# 21  31.8484°N 106.4270°W
# 22   36.1718°N 86.7850°W
# 23   42.3830°N 83.1022°W
# 24   35.4671°N 97.5137°W
# 25  45.5370°N 122.6500°W
# 26  36.2292°N 115.2601°W
# 27   35.1028°N 89.9774°W
# 28   38.1654°N 85.6474°W
# 29   39.3000°N 76.6105°W
# ..                   ...
# 70   28.4166°N 81.2736°W
# 71  33.6784°N 117.7713°W
# 72   40.7242°N 74.1726°W
# 73   35.9811°N 78.9029°W
# 74  32.6277°N 117.0152°W
# 75   41.6641°N 83.5819°W
# 76   41.0882°N 85.1439°W
# 77   27.7620°N 82.6441°W
# 78   27.5604°N 99.4892°W
# 79   40.7114°N 74.0648°W
# 80  33.2829°N 111.8549°W
# 81   43.0878°N 89.4299°W
# 82  33.5656°N 101.8867°W
# 83  33.6843°N 111.8611°W
# 84  39.5491°N 119.8499°W
# 85   42.8925°N 78.8597°W
# 86  33.3103°N 111.7431°W
# 87  33.5331°N 112.1899°W
# 88  36.2857°N 115.0939°W
# 89   36.1027°N 80.2610°W
# 90   36.6794°N 76.3018°W
# 91   36.9230°N 76.2446°W
# 92  37.4945°N 121.9412°W
# 93   32.9098°N 96.6303°W
# 94   32.8577°N 96.9700°W
# 95   25.8699°N 80.3029°W
# 96   37.5314°N 77.4760°W
# 97  43.6002°N 116.2317°W
# 98  47.6669°N 117.4333°W
# 99   30.4422°N 91.1309°W
#
# [100 rows x 11 columns]

# %%
df.CITY.head(50)
# Out:
# 0              New York
# 1           Los Angeles
# 2               Chicago
# 3               Houston
# 4               Phoenix
# 5          Philadelphia
# 6           San Antonio
# 7             San Diego
# 8                Dallas
# 9              San Jose
# 10               Austin
# 11         Jacksonville
# 12           Fort Worth
# 13             Columbus
# 14            Charlotte
# 15        San Francisco
# 16         Indianapolis
# 17              Seattle
# 18               Denver
# 19           Washington
# 20               Boston
# 21              El Paso
# 22            Nashville
# 23              Detroit
# 24        Oklahoma City
# 25             Portland
# 26            Las Vegas
# 27              Memphis
# 28           Louisville
# 29            Baltimore
# 30            Milwaukee
# 31          Albuquerque
# 32               Tucson
# 33               Fresno
# 34                 Mesa
# 35           Sacramento
# 36              Atlanta
# 37          Kansas City
# 38     Colorado Springs
# 39                Omaha
# 40              Raleigh
# 41                Miami
# 42           Long Beach
# 43    Virginia Beach[m]
# 44              Oakland
# 45          Minneapolis
# 46                Tulsa
# 47                Tampa
# 48            Arlington
# 49          New Orleans
# Name: CITY, dtype: object

# %%
data_path = constants.DENVER_POLICE_PATH
df_denver = pd.read_csv(str(data_path))
df_denver.columns
# Out:
# Index(['INCIDENT_NUMBER', 'INCIDENT_DATE', 'INCIDENT_TIME', 'DAY_OF_WEEK',
#        'INITIAL_CONTACT', 'CONTACT_BASIS', 'STREET_ADDRESS', 'CITY_STATE',
#        'LAST_FIRST_NAME', 'ROLE', 'OFFICER_RANK', 'BADGE_NUMBER',
#        'DUTY_STATUS', 'UNIFORM_PLAINCLOTHES', 'GENDER', 'AGE', 'RACE',
#        'ETHNICITY', 'ARMED_WITH', 'DISCHARGED_FIREARM', 'CASUALTY',
#        'DECISION_LETTER_URL', 'X_COORDINATE', 'Y_COORDINATE'],
#       dtype='object')

# %% [markdown]
# ## Denver Columns
#
# * 'INCIDENT_NUMBER',
# * 'INCIDENT_DATE',
# * 'INCIDENT_TIME',
# * 'DAY_OF_WEEK',
# * 'INITIAL_CONTACT',
# * 'CONTACT_BASIS',
# * 'STREET_ADDRESS',
# * 'CITY_STATE',
# * 'LAST_FIRST_NAME',
# * 'ROLE',
# * 'OFFICER_RANK',
# * 'BADGE_NUMBER',
# * 'DUTY_STATUS',
# * 'UNIFORM_PLAINCLOTHES',
# * 'GENDER',
# * 'AGE',
# * 'RACE',
# * 'ETHNICITY',
# * 'ARMED_WITH',
# * 'DISCHARGED_FIREARM',
# * 'CASUALTY',
# * 'DECISION_LETTER_URL',
# * 'X_COORDINATE',
# * 'Y_COORDINATE'

# %% [markdown]
# ## New York City
#
# can't find anything

# %% [markdown]
# ##
